# %% [markdown]
# <a href="https://colab.research.google.com/github/lolisguarana/Projeto-pandas/blob/main/ProjetoDIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/Vendas.xlsx")

# %%
df.head()
# Out:
#      Produto  Qtde    Preço       Data
# 0    Celular   1.0  2999.99 2022-06-01
# 1  Chocolate   2.0    29.99 2022-01-06
# 2      Blusa   5.0   199.99 2022-01-06
# 3     Sapato   1.0   299.99 2022-01-06
# 4      Bolsa   1.0   999.99 2022-01-06

# %%
df.dtypes
# Out:
# Produto            object
# Qtde              float64
# Preço             float64
# Data       datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#      Produto  Qtde    Preço       Data
# 0    Celular   1.0  1254.85 2020-12-01
# 1  Chocolate   NaN      NaN        NaT

# %%
df.head()
# Out:
#      Produto  Qtde    Preço       Data
# 0    Celular   1.0  1254.85 2020-12-01
# 1  Chocolate   NaN      NaN        NaT

# %%
df.head()
# Out:
#    Produto  Qtde    Preço       Data
# 0  Celular     1  1254.85 2020-12-01

# %%
df.sample(5)
# Out:
#      Produto  Qtde    Preço       Data
# 7     Tablet   NaN      NaN        NaT
# 3     Sapato   1.0   299.99 2022-01-06
# 1  Chocolate   2.0    29.99 2022-01-06
# 4      Bolsa   1.0   999.99 2022-01-06
# 0    Celular   1.0  2999.99 2022-06-01

# %%
df.isnull().sum()
# Out:
# Produto    0
# Qtde       2
# Preço      2
# Data       2
# dtype: int64

# %%
df["Preço"].fillna(df["Preço"].mean(), inplace=True)

# %%
df["Preço"].mean()
# Out:
# 1229.7975000000001

# %%
df.sample(5)
# Out:
#       Produto  Qtde      Preço       Data
# 1   Chocolate   2.0    29.9900 2022-01-06
# 8  Computador   1.0  1229.7975 2022-02-08
# 2       Blusa   5.0   199.9900 2022-01-06
# 0     Celular   1.0  2999.9900 2022-06-01
# 3      Sapato   1.0   299.9900 2022-01-06
